# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np
import csv

# %%
FANPAGE_LINK = "sieuanhhungMarvel"
FOLDER_PATH = "Data"
COOKIE_PATH = "./cookies.txt"
PAGES_NUMBER = 10

user_email = "tomnguyen02102022@gmail.com"
user_password = "34md506647"

# %%
post_list = []
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    extra_info=True, pages=PAGES_NUMBER, credentials=(user_email, user_password)):
    print(post)
    post_list.append(post)
# Out:
# /home/vnn04/miniconda3/envs/ml-env/lib/python3.12/site-packages/facebook_scraper/facebook_scraper.py:855: UserWarning: Facebook language detected as vi_VN - for best results, set to en_US
#   warnings.warn(
# ...

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".csv"
post_df_full.to_csv(path, index=False)
print(path)
# Out:
# DatasieuanhhungMarvel.csv

# %%
df = pd.read_csv('DatasieuanhhungMarvel.csv')
df.head(10)
# Out:
#            post_id                                               text  \
# 0  727161116121893  Khi được hỏi:"Ai là người đầu tiên rủ mày bắn ...
# 1  726771442827527                                               Ok 👌
#
#                                            post_text  shared_text  \
# 0  Khi được hỏi:"Ai là người đầu tiên rủ mày bắn ...          NaN
# 1                                               Ok 👌          NaN
#
#    original_text                 time   timestamp  \
# 0            NaN  2023-11-05 19:27:48  1699187268
# 1            NaN  2023-11-05 01:39:52  1699123192
#
#                                                image  \
# 0                                                NaN
# 1  https://scontent.fhan14-1.fna.fbcdn.net/v/t39....
#
#                                     image_lowquality  \
# 0  https://scontent.fhan14-4.fna.fbcdn.net/v/t15....
# 1  https://scontent.fhan14-1.fna.fbcdn.net/v/t39....
#
#                                               images  ...  \
# ...

# %%
start_post_id = "726771442827527"
start_crawling = False

post_list2 = []

for post in get_posts(FANPAGE_LINK,
                      options={"comments": True, "reactions": True, "allow_extra_requests": True},
                      extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH):

    if post['post_id'] == start_post_id:
        start_crawling = True

    if start_crawling:
        print(post)
        post_list2.append(post)
# Out:
# /home/vnn04/miniconda3/envs/ml-env/lib/python3.12/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# ...

# %%
post_list2.pop(0)
df2 = pd.DataFrame(post_list2)
df2
# Out:
#            post_id                                               text  \
# 0  726657189505619  Ông nào làm tạo hình cho anh trai quả mũ kì dữ...
# 1  726632232841448    Câu chuyện thường ngày ở nhà của mấy đứa mê mèo
# 2  726617332842938  "Nhật ký - Hell's Kitchen ngày 35/10/2023 ...\...
# 3  726541169517221                            "TVA, ASSEMBLE!" - Loki
# 4  726407516197253  "Bên chi nhánh TVA Bank mới tuyển được nhân sự...
# 5  726347992869872  Vụt qua trong trailer bóng dáng ai đó sắp có s...
# 6  726305062874165  Kingpin 👑 Một trong những phản diện đáng sợ nh...
#
#                                            post_text shared_text  \
# 0  Ông nào làm tạo hình cho anh trai quả mũ kì dữ...
# 1    Câu chuyện thường ngày ở nhà của mấy đứa mê mèo
# 2  "Nhật ký - Hell's Kitchen ngày 35/10/2023 ...\...
# 3                            "TVA, ASSEMBLE!" - Loki
# 4  "Bên chi nhánh TVA Bank mới tuyển được nhân sự...
# 5  Vụt qua trong trailer bóng dáng ai đó sắp có s...
# ...

# %%
with open("Data/DatasieuanhhungMarvel.csv", 'a', newline="") as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(post_list2)

# %%
df = pd.read_csv('DatasieuanhhungMarvel.csv')
df.head(10)
# Out:
#            post_id                                               text  \
# 0  727161116121893  Khi được hỏi:"Ai là người đầu tiên rủ mày bắn ...
# 1  726771442827527                                               Ok 👌
#
#                                            post_text  shared_text  \
# 0  Khi được hỏi:"Ai là người đầu tiên rủ mày bắn ...          NaN
# 1                                               Ok 👌          NaN
#
#    original_text                 time   timestamp  \
# 0            NaN  2023-11-05 19:27:48  1699187268
# 1            NaN  2023-11-05 01:39:52  1699123192
#
#                                                image  \
# 0                                                NaN
# 1  https://scontent.fhan14-1.fna.fbcdn.net/v/t39....
#
#                                     image_lowquality  \
# 0  https://scontent.fhan14-4.fna.fbcdn.net/v/t15....
# 1  https://scontent.fhan14-1.fna.fbcdn.net/v/t39....
#
#                                               images  ...  \
# ...
