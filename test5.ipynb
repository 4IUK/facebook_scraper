# %%
from facebook_scraper import _scraper
from facebook_scraper import *
import facebook_scraper as fs

# %%
email = "0563656200"
password = "34md506647"
_scraper.login(email, password)
cookies = _scraper.session.cookies
# Store & retrieve cookies
set_cookies(cookies)
# Check it worked
print(_scraper.is_logged_in())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/vnn04/Documents/facebook_scraper_page/test5.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/home/vnn04/Documents/facebook_scraper_page/test5.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> email = "0563656200"
#       <a href='vscode-notebook-cell:/home/vnn04/Documents/facebook_scraper_page/test5.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> password = "34md506647"
# ----> <a href='vscode-notebook-cell:/home/vnn04/Documents/facebook_scraper_page/test5.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> _scraper.login(email, password)
#       <a href='vscode-notebook-cell:/home/vnn04/Documents/facebook_scraper_page/test5.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> cookies = _scraper.session.cookies
#       <a href='vscode-notebook-cell:/home/vnn04/Documents/facebook_scraper_page/test5.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> # Store & retrieve cookies
#
# ...

# %%
post_list = []
for post in get_posts('sieuanhhungMarvel',
                    options={"comments": False, "reactions": False, "allow_extra_requests": False},
                    extra_info=False, pages=1000):
    print(post)
    post_list.append(post)
# Out:
# {'post_id': '735486241956047', 'text': 'Cuộc đình công của diễn viên vừa kết thúc là anh Tom Cứng Lên lại nhậu bí tỉ với đoàn làm phim trên phim trường của Venom 3. Không biết lần này anh phải đối đầu với nhân vật nào mà ông thì vui còn đoàn phim thì suy thế.', 'post_text': 'Cuộc đình công của diễn viên vừa kết thúc là anh Tom Cứng Lên lại nhậu bí tỉ với đoàn làm phim trên phim trường của Venom 3. Không biết lần này anh phải đối đầu với nhân vật nào mà ông thì vui còn đoàn phim thì suy thế.', 'shared_text': '', 'original_text': None, 'time': datetime.datetime(2023, 11, 20, 12, 19, 9), 'timestamp': 1700457549, 'image': None, 'image_lowquality': 'https://scontent.fhan14-4.fna.fbcdn.net/v/t39.30808-6/404558009_735485911956080_4438698362064910225_n.jpg?stp=cp0_dst-jpg_e15_q65_s320x320&_nc_cat=104&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=FpK4gqz9hE8AX8c69_2&_nc_ht=scontent.fhan14-4.fna&oh=00_AfB3sylCF-ODFyurhIyPeh4eKoLSXaD-R0y5Y5Vo4T_mDw&oe=655F3CCA', 'images': None, 'images_descri
# ...

# %%
post_list = []

for post in fs.get_posts(post_urls=['735485915289413'],
                    options={"comments": True, "reactions": True, "allow_extra_requests": True, 'shared_time':True, 'shared_user_id':True}):
    print(post)
    post_list.append(post)
# Out:
# /home/vnn04/miniconda3/envs/ml-env/lib/python3.12/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# ...

# %%
import pandas as pd

df = pd.DataFrame(post_list)
df
# Out:
#   original_request_url                                post_url  \
# 0      735485915289413  https://m.facebook.com/735486241956047
#
#            post_id                                               text  \
# 0  735486241956047  Hội hâm mộ Marvel\n\nCuộc đình công của diễn v...
#
#                                            post_text shared_text  \
# 0  Hội hâm mộ Marvel\n\nCuộc đình công của diễn v...        None
#
#   original_text                time timestamp  \
# 0          None 2023-11-19 22:00:00      None
#
#                                                image  ...  \
# 0  https://scontent.fhan14-3.fna.fbcdn.net/v/t39....  ...
#
#                                   w3_fb_url  \
# 0  https://www.facebook.com/735486241956047
#
#                                            reactions reaction_count  with  \
# 0  {'like': 744, 'love': 4, 'haha': 355, 'wow': 1...           1106  None
#
#   page_id sharers image_id image_ids was_live               fetched_time
# ...

# %%
df.iloc[0]
# Out:
# original_request_url                                               735485915289413
# post_url                                    https://m.facebook.com/735486241956047
# post_id                                                            735486241956047
# text                             Hội hâm mộ Marvel\n\nCuộc đình công của diễn v...
# post_text                        Hội hâm mộ Marvel\n\nCuộc đình công của diễn v...
# shared_text                                                                   None
# original_text                                                                 None
# time                                                           2023-11-19 22:00:00
# timestamp                                                                     None
# image                            https://scontent.fhan14-3.fna.fbcdn.net/v/t39....
# image_lowquality                 https://scontent.fhan14-3.fna.fbcdn.net/v/t39....
# ...

# %%
import time
post_list = []

for post in fs.get_posts(post_urls=['734285525409452'], 
                         options = {'reactors':True}):
    print(post['reactors'])
    post_list.append(post)
    time.sleep(0.1)
# Out:
# /home/vnn04/miniconda3/envs/ml-env/lib/python3.12/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# ...

# %%
from pprint import pprint
pprint(post_list[0])
# Out:
# {'available': True,
#  'comments': 82,
#  'comments_full': None,
#  'factcheck': None,
#  'fetched_time': datetime.datetime(2023, 11, 19, 7, 23, 13, 598820),
#  'image': None,
#  'image_lowquality': None,
#  'images': None,
#  'images_description': None,
#  'images_lowquality': None,
#  'images_lowquality_description': None,
#  'is_live': False,
#  'likes': 1560,
#  'link': 'https://media4.giphy.com/media/v1.Y2lkPTk5OWFjZWFjZHRxaTRnbXVjejk1Y2F1bzZsOGt6YjdlNmg4bmVoZWh4NnVoejBnayZlcD12MV9naWZzX3NlYXJjaCZjdD1n/sDcfxFDozb3bO/giphy.gif?fbclid=IwAR1BU95nptN6mRmla-AybyYrK0r36GsGcelpoRzyAPtefEFwr2JnC8N6WEE',
#  'links': [],
#  'original_request_url': '734285525409452',
#  'original_text': None,
#  'page_id': None,
#  'post_id': '734285772076094',
#  'post_text': 'Hội hâm mộ Marvel\n'
#               '\n'
#               'Nếu như Pedro một mình cân tất cả các vai ở Fantastic Four thì '
#               'sẽ kiểu…\n'
#               'See Translation',
# ...

# %%
pprint(post_list[0]['reactors'])
# Out:
# [{'link': 'https://facebook.com/profile.php?id=100095190619787&eav=AfbJQp00S-PCMk2QZg24W6Y_lFZwJ-laT9fRASfipBu0EUIoEhLCKm54Yd9jAblWZPk&fref=pb&paipv=0',
#   'name': 'Anh Kirisagi',
#   'type': 'haha'},
#  {'link': 'https://facebook.com/profile.php?id=100093996697870&eav=Afa3yI4bRzWBuoeEUOXJo_-81t4248LiyThpCuOldwZEG8u5BGvAaxRhEYRgJXzPbsc&fref=pb&paipv=0',
#   'name': 'Đặng Nhật Minh',
#   'type': 'like'},
#  {'link': 'https://facebook.com/profile.php?id=100093527534811&eav=AfbqSdRhALSqaNCZ1O5YLcjHEWCJa3aj5zF-9dPV8KTG8FdHRFVE8HuWYbDm9rrdnts&fref=pb&paipv=0',
#   'name': 'Trần Công Vu',
#   'type': 'like'},
#  {'link': 'https://facebook.com/profile.php?id=100092838360857&eav=Afa8eBLdAFEfDlWlpS5QZ6fFOcdKc_tfRz7V-elYhUyKLhihlGuYL0mv2VBr8puWEmU&fref=pb&paipv=0',
#   'name': 'Tạ Quang Huy',
#   'type': 'like'},
#  {'link': 'https://facebook.com/User.faci.vaz?eav=AfZ_r8rFpns7Ybt32Oasn3R9i_bFeC6oGC8u5lwqFdFtbjw4kZ4bmfKiIsbULXKvWVs&fref=pb&paipv=0',
#   'name': 'Vinh Nguyễn Phúc',
# ...

# %%
a = post_list[0]['reactors']
print(len(a))
# Out:
# 2668

# %%
print(len(post_list))
# Out:
# 15

# %%
df = pd.DataFrame(post_list)
df.head()
# Out:
#            post_id                                               text  \
# 0  731679755670029          Một nhà hiền triết quê Thái Bình từng nói
# 1  731627755675229  Lời tiên tri của Odin năm xưa đã thành sự thật...
# 2  731559542348717   Con trai Thần Chiến Tranh, cháu nội Thần Zeus...
# 3  731511015686903  Sứ mệnh của mỗi Loki được hoàn thành, khi hắn ...
# 4  731510672353604  Cá nhân ad rất thích màn thể hiện lần này của ...
#
#                                            post_text shared_text  \
# 0          Một nhà hiền triết quê Thái Bình từng nói
# 1  Lời tiên tri của Odin năm xưa đã thành sự thật...
# 2   Con trai Thần Chiến Tranh, cháu nội Thần Zeus...
# 3  Sứ mệnh của mỗi Loki được hoàn thành, khi hắn ...
# 4  Cá nhân ad rất thích màn thể hiện lần này của ...
#
#                                       original_text                time  \
# 0                                              None 2023-11-13 23:42:17
# ...

# %%
reactor = df.iloc[2]['reactors']

# %%
df_reactor = pd.DataFrame(reactor)
df_reactor
# Out:
#                                 name  \
# 0                       Thanh Duy Lê
# 1                        Minh Nguyen
# 2                            Viet Vu
# 3                           Lê Khánh
# 4                       Anh Kirisagi
# 5                         Limit Jtad
# 6                      Đào Minh Tiến
# 7                           Hùng Jr.
# 8                           Tuan Anh
# 9                          Quân Minh
# 10                Chỉ Để Comment Dạo
# 11               Mai Nguyễn Gia Minh
# 12                         Duck Ngáo
# 13                      Đặng Như NhÝ
# 14                      Hoang Khanhs
# 15                    Khôi The Khoai
# 16                     Minh MinhMinh
# 17                           Vũ Hiếu
# 18                     Hoàng Gia Bảo
# 19                     Lâm Đăng Khoa
# 20                           Viet Vu
# 21                         Nhật Minh
# 22                           Phạm An
# 23                    Hoàng Thành Võ
# ...

# %%
import pprint

post_id = '731559542348717'

fs.set_cookies("cookies.txt")
post = next(fs.get_posts(post_urls=["731559542348717"], options={"reactors": True, "comments": True}))
pprint.pprint(post)
# Out:
# /home/vnn04/miniconda3/envs/ml-env/lib/python3.12/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# {'available': True,
#  'comments': 133,
#  'comments_full': [{'comment_id': '670885341851151',
#                     'comment_image': None,
#                     'comment_reaction_count': None,
#                     'comment_reactions': None,
#                     'comment_reactors': [],
#                     'comment_text': 'Là sao ta😆',
#                     'comment_time': datetime.datetime(2023, 11, 14, 0, 0),
#                     'comment_url': 'https://facebook.com/670885341851151',
#                     'commenter_id': '100056267836140',
#                     'commenter_meta': None,
#                     'commenter_name': 'Lương Huy Hiệp',
# ...

# %%
text = post['comments_full']
print(text)
# Out:
# [{'comment_id': '670885341851151', 'comment_url': 'https://facebook.com/670885341851151', 'commenter_id': '100056267836140', 'commenter_url': 'https://facebook.com/huyhiep.luong.1?eav=AfaCJUqssOlRLjgeoOOzsCCywOnXdudBwA5vAD1Rsdc8y1xKxsJ-tDpU2IYqROPg4WA&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Lương Huy Hiệp', 'commenter_meta': None, 'comment_text': 'Là sao ta😆', 'comment_time': datetime.datetime(2023, 11, 14, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': [{'comment_id': '735494355089845', 'comment_url': 'https://facebook.com/735494355089845', 'commenter_id': '100089349583504', 'commenter_url': 'https://facebook.com/profile.php?id=100089349583504&eav=AfaPCbBcM0_AhOvcAGsY2_htwhCVMu1P5s97fqPHUbjF0YDuc62h0M1_B-hyfkbCv-4&fref=nf&rc=p&__tn__=R&paipv=0', 'commenter_name': 'Vũ Huyền', 'commenter_meta': None, 'comment_text': 'Lương Huy Hiệp zeus phich dao đẻ ra thằng á thần kratos -> kratos xử hết 
# ...

# %%
df = pd.DataFrame(text)

# %%
df
# Out:
#           comment_id                            comment_url     commenter_id  \
# 0    670885341851151   https://facebook.com/670885341851151  100056267836140
# 1    829506295522892   https://facebook.com/829506295522892  100003874260882
# 2    994579914952005   https://facebook.com/994579914952005  100056704315952
# 3    189793887512575   https://facebook.com/189793887512575  100000086157272
# 4   1117820135874411  https://facebook.com/1117820135874411  100041359762126
# 5   1407099423523402  https://facebook.com/1407099423523402  100095305247576
# 6    669855634996558   https://facebook.com/669855634996558  100023285793548
# 7   1020429052499353  https://facebook.com/1020429052499353  100006192254524
# 8   1728078887619069  https://facebook.com/1728078887619069  100032729983667
# 9   1292983321266886  https://facebook.com/1292983321266886  100030713144599
# 10  1822870784810944  https://facebook.com/1822870784810944  100001979767649
# ...

# %%
rep1 = df.iloc[0].replies
rep1
# Out:
# [{'comment_id': '735494355089845',
#   'comment_url': 'https://facebook.com/735494355089845',
#   'commenter_id': '100089349583504',
#   'commenter_url': 'https://facebook.com/profile.php?id=100089349583504&eav=AfaPCbBcM0_AhOvcAGsY2_htwhCVMu1P5s97fqPHUbjF0YDuc62h0M1_B-hyfkbCv-4&fref=nf&rc=p&__tn__=R&paipv=0',
#   'commenter_name': 'Vũ Huyền',
#   'commenter_meta': None,
#   'comment_text': 'Lương Huy Hiệp zeus phich dao đẻ ra thằng á thần kratos -> kratos xử hết thần hy lạp rồi đến bắc âu ở -> ra thằng con là atreus aka loki theo sự kiện ragnarok',
#   'comment_time': datetime.datetime(2023, 11, 14, 0, 0),
#   'comment_image': 'https://scontent.fhan5-8.fna.fbcdn.net/m1/v/t6/An_F9bJG7govfshSMBkvcRLcxT0jmiXVYKtr7lgH5AHgUrjjpZ1OD0xyxXYgf7arc0lWgCdrR_KN4Mg7RSN3Gm3W6Gg03N1tQ-ZXzVvFJ_KvvB4.png?ccb=10-5&oh=00_AfAP1INCxyorUHsZmSWV4aBt54tNS_zFje5aOqZioH_Sog&oe=657CF627&_nc_sid=7da55a',
#   'comment_reactors': [{'name': 'Lương Huy Hiệp',
# ...

# %%
a = []
for reaction in fs.get_posts(post_urls=['734518898719448'], options={'reactions':True, 'comments':True}):
    a.append(reaction)
# Out:
# /home/vnn04/miniconda3/envs/ml-env/lib/python3.12/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")

# %%
print(a)
# Out:
# [{'original_request_url': '734518898719448', 'post_url': 'https://facebook.com/story.php?story_fbid=734518898719448&id=100064840322550', 'post_id': 734518898719448, 'text': 'Các bạn nam chắc ai cũng muốn học chiêu pause time này để dành khi cãi nhau với người yêu :))', 'post_text': 'Các bạn nam chắc ai cũng muốn học chiêu pause time này để dành khi cãi nhau với người yêu :))', 'shared_text': '', 'original_text': None, 'time': datetime.datetime(2023, 11, 18, 22, 40, 26), 'timestamp': 1700322026, 'image': 'https://scontent.fhan14-3.fna.fbcdn.net/v/t39.30808-6/402264624_734518948719443_5938829508463439003_n.jpg?stp=cp0_dst-jpg_e15_fr_q65&_nc_cat=103&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=NRb9YeaNfLQAX8vu_qC&_nc_ht=scontent.fhan14-3.fna&oh=00_AfAjFgefRSIX1kY3a2ezHSJdrzWEA3MfAYqls9krjChHzA&oe=6560B153&manual_redirect=1', 'image_lowquality': 'https://scontent.fhan14-3.fna.fbcdn.net/v/t39.30808-6/402264624_734518948719443_5938829508463439003_n.jpg?stp=cp0_dst-jpg_e15_p160x160_q65&_
# ...

# %%
from pprint import pprint

pprint(a[0])
# Out:
# {'available': True,
#  'comments': 95,
#  'comments_full': [{'comment_id': '302120192733098',
#                     'comment_image': 'https://scontent.fhan14-3.fna.fbcdn.net/m1/v/t6/An_F9bJG7govfshSMBkvcRLcxT0jmiXVYKtr7lgH5AHgUrjjpZ1OD0xyxXYgf7arc0lWgCdrR_KN4Mg7RSN3Gm3W6Gg03N1tQ-ZXzVvFJ_KvvB4.png?ccb=10-5&oh=00_AfC1gJMH6lO_4VQyAnmcgj0JYE3GP2RZhSTaXWwCxgd13Q&oe=65827467&_nc_sid=7da55a',
#                     'comment_reaction_count': 42,
#                     'comment_reactions': {'haha': 34, 'like': 7, 'sad': 1},
#                     'comment_reactors': [{'link': 'https://facebook.com/profile.php?id=100093996697870&eav=AfY_-EDACPiDVtD3vLugkhMukgtcZdY28j2CoL1VsotsbUM_JY3_h6E20w91GytsuZM&fref=pb&paipv=0',
#                                           'name': 'Đặng Nhật Minh',
#                                           'type': 'haha'},
# ...
